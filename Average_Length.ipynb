# %%
import os
import pandas as pd
from VSA_utilities import date_from_int, describe_lens, get_durs

# %%
storage = "/Volumes/Data/Research/Healthy Brain Network/Voice Sample Data"
usable_table = pd.read_excel(os.path.join(storage, "Post-MRI Audio Video", "Usable Voice Samples.xlsx"))
usable_table["Date of recording"] = usable_table["Date of recording"].apply(date_from_int)

# %%
for sample_type in os.listdir(storage):
    sam = os.path.join(storage, sample_type)
    if os.path.isdir(sam):
        print(sample_type)
        usable, all_samples, dd = get_durs(sam, usable_table)
        print("\n{0}:".format(sam))
        for lens in [(usable, "… usable"), (all_samples, "… all")]:
            print(describe_lens(lens[0], lens[1]))
        print('\n')

# %%
usable, all_samples, dd = get_durs(storage, usable_table)
print(describe_lens(all_samples, 'all'))
# Out:
# Loading directory `GFTA`
# Loading directory `5000677`
# … Loading 5000677_GFTA.MP3
# Loading directory `5002406`
# … Loading 5002406_GFTA.MP3
# Loading directory `5005437`
# … Loading 5005437_GFTA.MP3
# Loading directory `5007611`
# … Loading 5007611 GFTA.MP3
# Loading directory `5011146`
# … Loading 5011146_GFTA.MP3
# Loading directory `5013573`
# … Loading 5013473_GFTA.MP3
# Loading directory `5020640`
# … Loading 5020640_GFTA.MP3
# Loading directory `5022889`
# … Loading 5022889_GFTA.MP3
# Loading directory `5024488`
# … Loading 5024488_GFTA.MP3
# Loading directory `5028550`
# … Loading 5028550_GFTA.MP3
# Loading directory `5032610`
# … Loading 5032610_GFTA.MP3
# Loading directory `5034881`
# … Loading 5034881_GFTA.MP3
# Loading directory `5040514`
# … Loading 5040514_GFTA.MP3
# Loading directory `5041333`
# … Loading 5041333_GFTA.MP3
# Loading directory `5041416`
# … Loading 5041416_GFTA.MP3
# Loading directory `5042427`
# … Loading 5042427_GFTA.MP3
# ...
